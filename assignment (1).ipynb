# %% [markdown]
# 1. Can we use Bagging for regression problems?

# %% [markdown]
# ans.yes

# %% [markdown]
# 2.What is the difference between multiple model training and single model training.

# %% [markdown]
# ans.The output is aggregated by ensemble technique of different models in multiple model training.
# while in single model training output is taken care by algorithm itself.

# %% [markdown]
# 3.Explain the concept of feature randomness in Random Forest.

# %% [markdown]
# ans.In Random Forest, feature randomness, also called feature bagging or the random subspace method, means that at each split in a decision tree within the forest, a random subset of the features is considered, not all features. This introduces more randomness into the model, leading to more diverse and less correlated trees, which generally improves the overall model performance.

# %% [markdown]
# 4. What is OOB (Out-of-Bag) Score.

# %% [markdown]
# ans.part of training data left unused during training individual model are used for evaluation ,and the score linked is oob score.

# %% [markdown]
# 5.How can you measure the importance of features in a Random Forest model.

# %% [markdown]
# ans.The feature importance in Random Forest can be determined using a metric called Gini importance. It measures the total reduction of the Gini impurity of the dataset when a particular feature is used for splitting. The higher the Gini importance, the more important the feature is for the mode

# %% [markdown]
# 6.Explain the working principle of a Bagging Classifier.

# %% [markdown]
# ans.A Bagging classifier is an ensemble meta-estimator that fits base classifiers each on random subsets of the original dataset and then aggregate their individual predictions (either by voting or by averaging) to form a final prediction.

# %% [markdown]
# 7.How do you evaluate a Bagging Classifier’s performance.

# %% [markdown]
# ans.To evaluate a Bagging Classifier's performance, you typically use metrics like accuracy, precision, recall, F1-score, and AUC (Area Under the Curve) on a test dataset. You also compare the ensemble model's performance to the individual base model's performance and use cross-validation to assess the model's generalizability.

# %% [markdown]
# 8. How does a Bagging Regressor work?

# %% [markdown]
# ans.A Bagging regressor is an ensemble meta-estimator that fits base regressors each on random subsets of the original dataset and then aggregate their individual predictions (either by voting or by averaging) to form a final prediction.

# %% [markdown]
# 9. What is the main advantage of ensemble techniques.

# %% [markdown]
# ans.The main advantage of ensemble techniques is improved accuracy and performance compared to using a single model. By combining multiple models, ensemble methods can leverage the strengths of different algorithms and reduce the impact of individual model biases, leading to more robust and reliable predictions.

# %% [markdown]
# 10. What is the main challenge of ensemble methods.

# %% [markdown]
# ans.The main challenge of ensemble methods is achieving diversity and independence among the base models while maintaining their individual accuracy. This ensures that the ensemble's predictions are not dominated by any single model, leading to more robust and accurate overall performance.

# %% [markdown]
# 11. Explain the key idea behind ensemble techniques.

# %% [markdown]
# ans.Ensemble techniques in machine learning combine the predictions of multiple models (called "weak learners") to create a stronger, more accurate model (called "strong learner"). The key idea is that the collective wisdom of many models can outperform any single model, leading to improved performance, reduced overfitting, and increased robustness.

# %% [markdown]
# 12. What is a Random Forest Classifier.

# %% [markdown]
# ans.A Random Forest classifier is a machine learning algorithm that uses an ensemble of decision trees to classify data, making predictions by aggregating the results of multiple trees, which are trained on different subsets of the data and features.

# %% [markdown]
# 13.What are the main types of ensemble techniques.

# %% [markdown]
# ans.The main types of ensemble techniques are Bagging, Boosting, Stacking, Voting, and Blending. These techniques combine multiple models to improve prediction accuracy, robustness, and generalization in machine learning.

# %% [markdown]
# 14.What is ensemble learning in machine learning.

# %% [markdown]
# ans.Ensemble learning in machine learning is a powerful technique where multiple individual models are combined to create a stronger, more accurate model. Instead of relying on a single model's predictions, ensemble methods aggregate the outputs of diverse models to enhance predictive performance and reduce errors.

# %% [markdown]
# 15.When should we avoid using ensemble methods.

# %% [markdown]
# ans.Ensemble methods should be avoided when simplicity and interpretability are crucial, and when computational resources are limited. Additionally, if the problem is very well-suited to a single, well-tuned model, an ensemble might not offer significant benefits or even degrade performance.

# %% [markdown]
# 16.2 How does Bagging help in reducing overfitting.

# %% [markdown]
# ans.Bagging reduces overfitting by training multiple models on different random subsets of the training data and averaging their predictions. This introduces diversity among the models, making the ensemble less sensitive to outliers and noise, and improving generalization to unseen data.

# %% [markdown]
# 17.Why is Random Forest better than a single Decision Tree.

# %% [markdown]
# ans.Random Forests typically outperform single Decision Trees because they're less prone to overfitting and offer better generalization due to their ensemble nature. By combining multiple decision trees, Random Forests reduce variance and improve prediction accuracy.

# %% [markdown]
# 18.What is the role of bootstrap sampling in Bagging

# %% [markdown]
# ans.sampling with replacement in rows.

# %% [markdown]
# 19.What are some real-world applications of ensemble techniques.

# %% [markdown]
# ans.Ensemble techniques, which combine multiple models, are used in a wide range of real-world applications, including remote sensing, financial forecasting, and computer security. They improve accuracy and robustness in areas like medical diagnosis, stock prediction, and image classification.

# %% [markdown]
# 20.What is the difference between Bagging and Boosting.

# %% [markdown]
# ans.Bagging and boosting are both ensemble methods that combine multiple models to improve machine learning performance, but they differ in how they train and combine these models. Bagging, or bootstrap aggregating, trains models independently in parallel, focusing on reducing variance and overfitting, while boosting trains models sequentially, each correcting the errors of the previous model and focusing on reducing bias.

# %%
#pratical

# %% [markdown]
# 21.Train a Bagging Classifier using Decision Trees on a sample dataset and print model accuracy.

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X, y = make_classification(n_samples = 1000, n_features = 20, n_classes=2, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.ensemble import BaggingClassifier

# %%
dct=DecisionTreeClassifier()

# %%
bag=BaggingClassifier(estimator=dct,n_estimators=11,verbose=2)

# %%
bag
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=11,
#                   verbose=2)

# %%
bag.fit(X_train,y_train)
# Out:
# Building estimator 1 of 11 for this parallel run (total 11)...
# Building estimator 2 of 11 for this parallel run (total 11)...
# Building estimator 3 of 11 for this parallel run (total 11)...
# Building estimator 4 of 11 for this parallel run (total 11)...
# Building estimator 5 of 11 for this parallel run (total 11)...
# Building estimator 6 of 11 for this parallel run (total 11)...
# Building estimator 7 of 11 for this parallel run (total 11)...
# Building estimator 8 of 11 for this parallel run (total 11)...
# Building estimator 9 of 11 for this parallel run (total 11)...
# Building estimator 10 of 11 for this parallel run (total 11)...
# Building estimator 11 of 11 for this parallel run (total 11)...
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=11,
#                   verbose=2)

# %%
y_pred=bag.predict(X_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8333333333333334

# %% [markdown]
# 22.Train a Bagging Regressor using Decision Trees and evaluate using Mean Squared Error (MSE).

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.datasets import make_regression
X, y = make_regression(n_samples = 1000, n_features = 20, n_targets=1, noise=3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
dec=DecisionTreeRegressor()
reg=BaggingRegressor(estimator=dec,n_estimators=11) #BY DEFAULT decisiontreeregressor as a estimator

# %%
reg.fit(X_train,y_train)
# Out:
# BaggingRegressor(estimator=DecisionTreeRegressor(), n_estimators=11)

# %%
y_pred=reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7192130430558329

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 9906.470494071986

# %% [markdown]
# 23.Train a Random Forest Classifier on the Breast Cancer dataset and print feature importance scores.

# %%
import pandas as pd
df=pd.read_csv("breast-cancer.csv")

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
df["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df["diagnosis"]=df["diagnosis"].map({"M":1,"B":0})

# %%
df["diagnosis"].dtype
# Out:
# dtype('int64')

# %%
df.drop("id",axis=1,inplace=True)

# %%
x=df.drop("diagnosis",axis=1)
y=df["diagnosis"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf=RandomForestClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9532163742690059

# %% [markdown]
# 24.Train a Random Forest Regressor and compare its performance with a single Decision Tree

# %%
from sklearn.datasets import make_regression
x,y=make_regression(n_samples=1000,n_features=1,n_targets=1,noise=2)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)
from sklearn.ensemble import RandomForestRegressor

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)
rf=RandomForestRegressor(n_estimators=1,criterion="squared_error")

# %%
rf
# Out:
# RandomForestRegressor(n_estimators=1)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1)

# %%
y_pred=rf.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9964826079321315

# %% [markdown]
# 25.Compute the Out-of-Bag (OOB) Score for a Random Forest Classifier.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)

# %%
rf_clf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=1)
rf_clf
# Out:
# RandomForestClassifier(oob_score=True, random_state=1)

# %%
rf_clf.fit(X, y)
# Out:
# RandomForestClassifier(oob_score=True, random_state=1)

# %%
rf_clf.oob_score_
# Out:
# 0.861

# %% [markdown]
# 25. Train a Bagging Classifier using SVM as a base estimator and print accuracy.

# %%
from sklearn.svm import SVC
svc=SVC()
bag_clf=BaggingClassifier(estimator=svc)

# %%
x, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
bag_clf
# Out:
# BaggingClassifier(estimator=SVC())

# %%
bag_clf.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=SVC())

# %%
y_pred=bag_clf.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8533333333333334

# %% [markdown]
# 26. Train a Random Forest Classifier with different numbers of trees and compare accuracy.

# %%
x, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
rf_clf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=1)
rf_clf  #n_estimator=100
# Out:
# RandomForestClassifier(oob_score=True, random_state=1)

# %%
rf_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=1)

# %%
y_pred=rf_clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8666666666666667

# %%
rf = RandomForestClassifier(n_estimators=10, oob_score=True, random_state=1)
rf  #n_estimator=10
# Out:
# RandomForestClassifier(n_estimators=10, oob_score=True, random_state=1)

# %%
rf.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:615: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# RandomForestClassifier(n_estimators=10, oob_score=True, random_state=1)

# %%
y_pred=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.87

# %%
#we get littlt more accuracy

# %% [markdown]
# 27.Train a Bagging Classifier using Logistic Regression as a base estimator and print AUC score.

# %%
from sklearn.linear_model import LogisticRegression

# %%
x, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)
log=LogisticRegression()

# %%
bag=BaggingClassifier(estimator=log,n_estimators=1)

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=LogisticRegression(), n_estimators=1)

# %%
y_pred=bag.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.84

# %%
y_pred_proba=bag.predict_proba(x_test)[:,0]

# %%
from sklearn.metrics import classification_report,roc_curve,auc
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       139
#            1       0.86      0.84      0.85       161
#
#     accuracy                           0.84       300
#    macro avg       0.84      0.84      0.84       300
# weighted avg       0.84      0.84      0.84       300

# %%
tpr,fpr,thresholds=roc_curve(y_test,y_pred_proba)

# %%
# Calculate ROC curve
import matplotlib.pyplot as plt
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Calculate AUC score
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', linewidth=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# 29.Train a Random Forest Regressor and analyze feature importance scores

# %%
x,y=make_regression(n_samples=1000,n_features=1,n_targets=1,noise=2)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)
from sklearn.ensemble import RandomForestRegressor

# %%
RandomForestRegressor()
from sklearn.ensemble import RandomForestClassifier

feature_names = [f"feature {i}" for i in range(X.shape[1])]
forest = RandomForestClassifier(random_state=0)
forest.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 6
#       4 feature_names = [f"feature {i}" for i in range(X.shape[1])]
#       5 forest = RandomForestClassifier(random_state=0)
# ----> 6 forest.fit(X_train, y_train)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:421, in BaseForest.fit(self, X, y, sample_weight)
#     414         raise ValueError(
# ...

# %% [markdown]
# 30..2 Train an ensemble model using both Bagging and Random Forest and compare accuracy.

# %%
x, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
bag=BaggingClassifier()
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_pred_bag=bag.predict(x_test)

# %%
accuracy_score(y_test,y_pred_bag)
# Out:
# 0.8166666666666667

# %%
clf=RandomForestClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.87

# %% [markdown]
# 31.Train a Random Forest Classifier and tune hyperparameters using GridSearchCV.

# %%
x, y = make_classification(n_samples=1000, n_features=2,n_informative=2,n_redundant=0,n_classes=2)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)
import seaborn as sns

# %%
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y)
# Out:
# <Axes: >

# %%
rf=RandomForestClassifier()

# %%
params={"n_estimators":[11,1,2,5,6,9],"criterion":["gini","log_loss"]}

# %%
params
# Out:
# {'n_estimators': [11, 1, 2, 5, 6, 9], 'criterion': ['gini', 'log_loss']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(rf,param_grid=params)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'log_loss'],
#                          'n_estimators': [11, 1, 2, 5, 6, 9]})

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'n_estimators': 11}

# %%
y_pred=grid.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.88

# %% [markdown]
# 32 Train a Bagging Regressor with different numbers of base estimators and compare performance.

# %%
from sklearn.datasets import make_regression
x,y=make_regression(n_samples=1000,n_features=1,n_targets=1,noise=2)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
bag=BaggingRegressor(n_estimators=10) #with estimator=10

# %%
bag
# Out:
# BaggingRegressor()

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingRegressor()

# %%
y_pred=bag.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9940254479866902

# %%
bag=BaggingRegressor(n_estimators=100) #with estimator=100

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingRegressor(n_estimators=100)

# %%
y_pred=bag.predict(x_test)

# %%
r2_score(y_test,y_pred) #little more accuracy here
# Out:
# 0.9942639833412401

# %% [markdown]
# 33.Train a Random Forest Classifier and analyze misclassified samples

# %%
x,y=make_classification(n_samples=1000,n_informative=2,n_features=2,n_redundant=0,n_classes=2,n_clusters_per_class=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y)
# Out:
# <Axes: >

# %%
clf=RandomForestClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
co=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(co,annot=True)
# Out:
# <Axes: >

# %%
#15,21 are misclassified datapoints

# %% [markdown]
# 34.Train a Bagging Classifier and compare its performance with a single Decision Tree Classifier.

# %%
x,y=make_classification(n_samples=1000,n_informative=2,n_features=2,n_redundant=0,n_classes=2,n_clusters_per_class=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
bag=BaggingClassifier(n_estimators=1)

# %%
bag
# Out:
# BaggingClassifier(n_estimators=1)

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier(n_estimators=1)

# %%
y_pred=bag.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9266666666666666

# %% [markdown]
# 35.Train a Random Forest Classifier and visualize the confusion matrix.

# %%
x,y=make_classification(n_samples=1000,n_informative=2,n_features=2,n_redundant=0,n_classes=2,n_clusters_per_class=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
clf=RandomForestClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
con_mat=confusion_matrix(y_test,y_pred)
print(con_mat)
# Out:
# [[113  21]
#  [ 29 137]]

# %%
sns.heatmap(con_mat,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 36.Train a Stacking Classifier using Decision Trees, SVM, and Logistic Regression, and compare accuracy.

# %% [markdown]
# 37.Train a Random Forest Classifier and print the top 5 most important features.

# %%
X, y = make_classification(n_samples=100, n_features=10, random_state=42)
df = pd.DataFrame(X, columns=[f'feature_{i}' for i in range(X.shape[1])])
df['target'] = y
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1), df['target'], test_size=0.2, random_state=42)

# 2. Train the Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)  # You can adjust n_estimators
rf_model.fit(X_train, y_train)

# 3. Get Feature Importances
feature_importances = rf_model.feature_importances_

# %%
feature_importances
# Out:
# array([0.2821054 , 0.05339149, 0.45032412, 0.08856058, 0.02730933,
#        0.01765327, 0.02469819, 0.01193403, 0.01391947, 0.03010412])

# %%
import numpy as np
sorted_indices = np.argsort(feature_importances)[::-1]  # Sort in descending order
top_5_indices = sorted_indices[:5]

# %%
top_5_indices
# Out:
# array([2, 0, 3, 1, 9], dtype=int64)

# %% [markdown]
# 38.Train a Bagging Classifier and evaluate performance using Precision, Recall, and F1-score.

# %%
x, y = make_classification(n_samples=100, n_features=10, random_state=42)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
bag=BaggingClassifier()

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_pred=bag.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        13
#            1       0.94      0.88      0.91        17
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# 39.04= Train a Random Forest Classifier and analyze the effect of max_depth on accuracy.

# %%
x, y = make_classification(n_samples=100, n_features=10, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
params={"max_depth":(10,15,20)}
clf=RandomForestClassifier()

# %%
grid=GridSearchCV(estimator=clf,param_grid=params,scoring="accuracy",verbose=2,cv=5)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV] END .......................................max_depth=10; total time=   0.7s
# [CV] END .......................................max_depth=10; total time=   0.5s
# [CV] END .......................................max_depth=10; total time=   0.5s
# [CV] END .......................................max_depth=10; total time=   0.5s
# [CV] END .......................................max_depth=10; total time=   0.6s
# [CV] END .......................................max_depth=15; total time=   0.6s
# [CV] END .......................................max_depth=15; total time=   0.5s
# [CV] END .......................................max_depth=15; total time=   0.5s
# [CV] END .......................................max_depth=15; total time=   0.5s
# [CV] END .......................................max_depth=15; total time=   0.5s
# [CV] END .......................................max_depth=20; total time=   0.5s
# ...

# %%
grid.best_params_
# Out:
# {'max_depth': 10}

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10)

# %% [markdown]
# 41. Train a Random Forest Classifier and evaluate its performance using ROC-AUC Score.

# %%
x, y = make_classification(n_samples=100, n_features=10, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
clf=RandomForestClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)
y_pred_proba=clf.predict_proba(x_test)[:,0]

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# %%
roc_auc = auc(fpr, tpr)

# %%
roc_auc
# Out:
# 0.033936651583710405

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', linewidth=2, label='ROC curve (area = %0.2f)' % roc_auc)

# %% [markdown]
# 43.Train a Random Forest Classifier and plot the Precision-Recall curv.

# %%
x, y = make_classification(n_samples=100, n_features=10, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)
clf=RandomForestClassifier()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
y_pred_proba=clf.predict_proba(x_test)[:,0]

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

# %%
roc_auc
# Out:
# 0.04072398190045249

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', linewidth=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# 44.Train a Bagging Regressor with different levels of bootstrap samples and compare performance
