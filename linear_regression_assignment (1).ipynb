# %% [markdown]
# 1. What does R-squared represent in a regression model.

# %% [markdown]
# ans.r square is percentage variation in y explained by x. it shows how data fits in a regression model.

# %% [markdown]
# 2.What are the assumptions of linear regression.

# %% [markdown]
# ans.the assumption of linear regression are:
#     1.linearity
#     2.each rows are independent
#     3.homoscadasity
#     4.error must bbe normally distributed.
#     5.features shows less multicollinearity

# %% [markdown]
# 3.What is the difference between R-squared and Adjusted R-squared.

# %% [markdown]
# ansR-squared measures the proportion of the variation in your dependent variable (Y) explained by your independent variables (X) for a linear regression model. Adjusted R-squared adjusts the statistic based on the number of independent variables in the model.

# %% [markdown]
# 4.Why do we use Mean Squared Error (MSE).

# %% [markdown]
# ans.there are many benefits of using MSE
# 1.It also used as a cost function to get the optimum value.
# 2.it is differentiable
# 3.errors should not cancel out each other.
# 4.it is convex function
# 5.it has one local and one global minima.

# %% [markdown]
# 5 What does an Adjusted R-squared value of 0.85 indicate.

# %% [markdown]
# ans.it x incresae then there is 85$ chance y will also increase.

# %% [markdown]
# 6.How do we check for normality of residuals in linear regression.

# %% [markdown]
# ans.If the plot shows the residuals approximately following a straight line, it suggests that the residuals are normally distributed

# %% [markdown]
# 7.What is multicollinearity, and how does it impact regression.

# %% [markdown]
# in multicollinearity,the feature  exhibits linear relationship with more then 2 variable.

# %% [markdown]
# in modal training ,memorisation happens if we donot deal with multicollinearity.

# %% [markdown]
# 8.What is Mean Absolute Error (MAE).

# %% [markdown]
# ans.mean absolute error is denoted by |(y_actual - y_predicted)|.

# %% [markdown]
# 9.What are the benefits of using an ML pipeline.

# %% [markdown]
# ans. Pipelines enable you to break down the machine learning process into modular, well-defined steps. Each step can be developed, tested and optimized independently, making it easier to manage and maintain the workflow.

# %% [markdown]
# 10. Why is RMSE considered more interpretable than MSE.

# %% [markdown]
# ans.there are some beneifits of using RSME over MSC
# 1.same unit
# 2.differentiable
# 3.less sensitive to outliers

# %% [markdown]
# 11.What is pickling in Python, and how is it useful in ML.

# %% [markdown]
# ans.In Python programming, 'pickling' refers to the process of converting a Python object into a byte stream, which can be stored in a file or transferred across a network. This process is also known as serialization or marshaling. it helps in transferring our code to othres

# %% [markdown]
# 12.What does a high R-squared value mean.

# %% [markdown]
# ans.high r square value mean that our model is good.

# %% [markdown]
# 12.What happens if linear regression assumptions are violated.

# %% [markdown]
# ans. Violation of this assumption is very serious–it means that your linear model probably does a bad job at predicting your actual (non-linear) data.

# %% [markdown]
# 13.How can we address multicollinearity in regression.

# %% [markdown]
# ans.multicollinearity in a dataset is not good thing, VIF is used to find multicollinearity remove that feature showing multicollinearity.

# %% [markdown]
# 14. How can feature selection improve model performance in regression analysis.

# %% [markdown]
# ans.Feature selection is a critical step in the machine learning pipeline that involves selecting the most relevant features from the dataset to improve model performance. By eliminating redundant or irrelevant features, one can reduce overfitting, enhance model interpretability, and improve accuracy.

# %% [markdown]
# 15.How is Adjusted R-squared calculated.

# %% [markdown]
# ![image.png](attachment:c897775f-3da0-4e55-824e-e5a2e9dbbdca.png)![image.png](attachment:f49816d8-8fe0-4d60-b01e-0001265d9d59.png)

# %% [raw]
# R² = r-squared of the model
# n = number of observations (data points)
# p = number of predictors (independent variables)

# %% [markdown]
# 17.Why is MSE sensitive to outliers.

# %% [markdown]
# ANS.Sensitivity to Outliers: MSE is sensitive to outliers due to the squaring of errors

# %% [markdown]
# 18.What is the role of homoscedasticity in linear regression.

# %% [markdown]
# ans.In a linear regression model, homoskedasticity occurs when the variance of the error term is constant. This indicates that the model is well-defined, meaning that the dependent variable is adequately defined by the predictor variable. If there is too much variance in the error term, the model isn't well-defined.

# %% [markdown]
# 19.What is Root Mean Squared Error (RMSE).

# %% [markdown]
# ans.The Root Mean Squared Error (RMSE) is one of the two main performance indicators for a regression model. It measures the average difference between values predicted by a model and the actual values. It provides an estimation of how well the model is able to predict the target value (accuracy).

# %% [markdown]
# 20.Why is pickling considered risky.

# %% [markdown]
# ans.Security Vulnerabilities: The most significant danger of using pickle is its inherent insecurity. When you unpickle data, you are essentially executing the byte stream as Python code. This means that if an attacker can modify the serialized data, they can execute arbitrary code on your system.

# %% [markdown]
# 21.What is heteroscedasticity, and why is it a problem.

# %% [markdown]
# ans.errors is not constant, with predicted value when plotted on graph.

# %% [markdown]
#  Heteroskedasticity refers to a situation where the variance of the residuals is unequal over a range of measured values. If heteroskedasticity exists, the population used in the regression contains unequal variance, the analysis results may be invalid.

# %% [markdown]
# 23. How can interaction terms enhance a regression model's predictive power?

# %% [markdown]
# ans.Add interaction terms as a multiplication of the original features. By adding these new variables to the regression model, you can measure the effects of the interaction between them and the target.

# %% [markdown]
# ###pratical part

# %% [markdown]
# 1.1. Write a Python script to visualize the distribution of errors (residuals) for a multiple linear regression model
# using Seaborn's "diamonds" dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("diamonds")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
x=df[["depth","table","price","x","y","z"]]
y=df[["carat"]]

# %%
x
# Out:
#        depth  table  price     x     y     z
# 0       61.5   55.0    326  3.95  3.98  2.43
# 1       59.8   61.0    326  3.89  3.84  2.31
# 2       56.9   65.0    327  4.05  4.07  2.31
# 3       62.4   58.0    334  4.20  4.23  2.63
# 4       63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   60.8   57.0   2757  5.75  5.76  3.50
# 53936   63.1   55.0   2757  5.69  5.75  3.61
# 53937   62.8   60.0   2757  5.66  5.68  3.56
# 53938   61.0   58.0   2757  6.15  6.12  3.74
# 53939   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 6 columns]

# %%
y
# Out:
#        carat
# 0       0.23
# 1       0.21
# 2       0.23
# 3       0.29
# 4       0.31
# ...      ...
# 53935   0.72
# 53936   0.72
# 53937   0.70
# 53938   0.86
# 53939   0.75
#
# [53940 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
x_train.shape,x_test.shape
# Out:
# ((40455, 6), (13485, 6))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[1.84853057e-02, 4.37912377e-03, 3.22933037e-05, 3.05614843e-01,
#         3.99724578e-03, 9.25893844e-04]])

# %%
model.intercept_
# Out:
# array([-2.49952555])

# %%
y_pred=model.predict(x_test)

# %%
error=y_test - y_pred

# %%
error
# Out:
#           carat
# 33828  0.043543
# 10290 -0.035229
# 26160 -0.187568
# 11988 -0.040490
# 28620  0.102512
# ...         ...
# 15132  0.021486
# 27045  0.064058
# 19415 -0.058598
# 25198  0.159769
# 18257 -0.111056
#
# [13485 rows x 1 columns]

# %%
plt.scatter(error,y_pred)
plt.xlabel("y_pred")
plt.ylabel("error")
plt.show()

# %% [markdown]
# 2. Write a Python script to calculate and print Mean Squared Error (MSE), Mean Absolute Error (MAE), and Root
# Mean Squared Error (RMSE) for a linear regression model.

# %%
#diamond dataset

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error,r2_score

# %%
x1=pd.DataFrame(np.random.randn(1000))
y1=pd.DataFrame(np.random.randn(1000))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linear=LinearRegression()
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linear.predict(x_test)

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 0.9373380374925375

# %%
 mean_absolute_error(y_pred,y_test)
# Out:
# 0.7643575078684667

# %% [markdown]
# 3.3. Write a Python script to check if the assumptions of linear regression are met. Use a scatter plot to check
# linearity, residuals plot for homoscedasticity, and correlation matrix for multicollinearity.

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
x=df.iloc[:,0:3]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[362], line 1
# ----> 1 model.fit(x_train,y_train)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:629, in LinearRegression.fit(self, X, y, sample_weight)
#     624 # Note that neither _rescale_data nor the rest of the fit method of
#     625 # LinearRegression can benefit from in-place operations when X is a
# ...

# %%
#residual
y_pred=model.predict(x_test)

# %%
error=y_pred - y_test

# %%
error

# %%
df

# %%
plt.scatter(df["feature1"],df["target"]) #feature1 shows linear relationship

# %%
plt.scatter(df["feature2"],df["target"]) #not sure about linearity

# %%
plt.scatter(df["feature3"],df["target"]) #feature 3 shows linear relation with target

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = []

for i in range(x_train.shape[1]):
    vif.append(variance_inflation_factor(x_train,i))

# %%
vif

# %%
#all vif is 1,which means no multicollinearity

# %%
#normal residual

# %%
sns.displot(error,kind="kde")    #errors are approxmately normal distributed

# %%
#homoscadascity

# %%
plt.scatter(y_pred,error)  #holds linearity

# %% [markdown]
# 4. Write a Python script that creates a machine learning pipeline with feature scaling and evaluates the
# performance of different regression models.

# %%
df=pd.read_csv("data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   feature1  200 non-null    float64
#  1   feature2  200 non-null    float64
#  2   feature3  200 non-null    float64
#  3   target    200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
x=df[["feature1"]]
y=df[["target"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
regressor.coef_
# Out:
# array([[78.92138653]])

# %%
from sklearn.metrics import r2_score,accuracy_score,classification_report

# %%
r2_score(y_pred,y_test)
# Out:
# 0.44480279463434946

# %% [markdown]
# 45. Implement a simple linear regression model on a dataset and print the model's coefficients, intercept, and
# R-squared score.

# %%
df=pd.read_csv("height-weight.csv")

# %%
x=df[["Weight"]]
y=df[["Height"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.linear_model import LinearRegression
regre=LinearRegression()
regre.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regre.predict(x_test)

# %%
regre.coef_
# Out:
# array([[1.01241575]])

# %%
regre.intercept_
# Out:
# array([83.26210536])

# %% [markdown]
# 6.6. Write a Python script that analyzes the relationship between total bill and tip in the 'tips' dataset using
# simple linear regression and visualizes the results.

# %%
df=sns.load_dataset("tips")

# %%
x=df[["tip"]]
y=df[["total_bill"]]
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(x,y) # it folows linear relationship

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
rege=LinearRegression()
rege.fit(x_train,y_train)
#y_pred=rege.predict(x_test)
# Out:
# LinearRegression()

# %%
rege.coef_
# Out:
# array([[4.64094275]])

# %%
rege.intercept_
# Out:
# array([5.83292281])

# %% [markdown]
# 7. Write a Python script that fits a linear regression model to a synthetic dataset with one feature. Use the
# model to predict new values and plot the data points along with the regression line.

# %%
x=np.random.randn(1000)
y=np.random.random(1000)
plt.scatter(x,y)

# %% [markdown]
# 8. Write a Python script that pickles a trained linear regression model and saves it to a file.

# %%
import pickle

# %%
model
# Out:
# LinearRegression()

# %%
pickle.dump(model,open("model.pkl","wb"))

# %% [markdown]
# 9. Write a Python script that fits a polynomial regression model (degree 2) to a dataset and plots the
# regression curve

# %%
np.random.seed(1)
X = 2*np.random.rand(100, 1)
#generate random synthetic y using X
y = 4 + 3*X+1.5*X**2 + np.random.randn(100, 1)
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly_train = poly_features.fit_transform(X_train)
from sklearn.linear_model import LinearRegression
poly_reg = LinearRegression()

# %%
poly_reg.fit(X_poly_train, y_train)
# Out:
# LinearRegression()

# %%
poly_reg.coef_
# Out:
# array([[2.19368573, 1.83687391]])

# %%
poly_reg.intercept_
# Out:
# array([4.37045389])

# %%
#make prediction on train data itself for the evaluation metrics
y_poly_predict = poly_reg.predict(X_poly_train)

# %%
plt.scatter(X_train, y_train, label = "training data")

# %%
degree = 2
plt.scatter(X_train, y_train, label = "training data")
X_range = np.linspace(0, 2, 100).reshape(-1, 1)
X_range_poly = poly_features.transform(X_range)
plt.plot(X_range, poly_reg.predict(X_range_poly), color='red', label=f'Polynomial Regression (Degree {degree})')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Polynomial Regression')
plt.legend()
plt.show()

# %% [markdown]
# 10.Generate synthetic data for simple linear regression (use random values for X and y) and fit a linear
# regression model to the data. Print the model's coefficient and intercept.

# %% [markdown]
# 11.Write a Python script that fits polynomial regression models of different degrees to a synthetic dataset and
# compares their performance

# %%
np.random.seed(1)
X = 2*np.random.rand(100, 1)
#generate random synthetic y using X
y = 4 + 3*X+1.5*X**2 + np.random.randn(100, 1)
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=3, include_bias=False)
X_poly_train = poly_features.fit_transform(X_train)
from sklearn.linear_model import LinearRegression
poly_reg = LinearRegression()

# %%
poly_reg.fit(X_poly_train, y_train)
#make prediction on train data itself for the evaluation metrics
y_poly_predict = poly_reg.predict(X_poly_train)

# %%
poly_reg.coef_
# Out:
# array([[ 0.82717662,  3.64351837, -0.61948795]])

# %%
from sklearn.metrics import r2_score

# %%
poly_reg.intercept_
# Out:
# array([4.56899387])

# %% [markdown]
# 12. Write a Python script that fits a simple linear regression model with two features and prints the model's
# coefficients, intercept, and R-squared score.

# %%
from sklearn.datasets import load_diabetes

# %%
data=load_diabetes()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df["target"]=data.target

# %%
x=df[["age","bmi"]]
y=df[["target"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scal=StandardScaler()

# %%
x_train=scal.fit_transform(x_train)

# %%
x_test=scal.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear=LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([[ 6.24982694, 43.95451847]])

# %%
linear.intercept_
# Out:
# array([153.9244713])

# %% [markdown]
# 13. Write a Python script that generates synthetic data, fits a linear regression model, and visualizes the
# regression line along with the data points.

# %%
df1=pd.DataFrame(np.random.randn(1000),columns=["col1"])

# %%
df2=pd.DataFrame(np.random.random(1000),columns=["col2"])

# %%
df=pd.concat([df1,df2],axis=1)

# %%
x=df[["col1"]]
y=df[["col2"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lin.coef_
# Out:
# array([[-0.00597416]])

# %%
lin.intercept_
# Out:
# array([0.51272499])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,y_test)
# Out:
# -177.18871183314457

# %% [markdown]
# 14. Write a Python script that uses the Variance Inflation Factor (VIF) to check for multicollinearity in a dataset
# with multiple features.

# %%
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df["price"]=data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %% [markdown]
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# vif=pd.DataFrame()
# vif[]df.columns
# vif

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif['VIF'] =[ variance_inflation_factor(df.values, i) for i in range(len(df.columns))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[416], line 3
#       1 from statsmodels.stats.outliers_influence import variance_inflation_factor
# ----> 3 vif['VIF'] =[ variance_inflation_factor(df.values, i) for i in range(len(df.columns))]
#
# NameError: name 'vif' is not defined

# %%
vif

# %% [markdown]
# 15. Write a Python script that generates synthetic data for a polynomial relationship (degree 4), fits a
# polynomial regression model, and plots the regression curve.

# %% [markdown]
# 16. Write a Python script that creates a machine learning pipeline with data standardization and a multiple
# linear regression model, and prints the R-squared score.

# %%
df=pd.read_csv("data.csv")

# %%
df.isnull().sum()
# Out:
# feature1    0
# feature2    0
# feature3    0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   feature1  200 non-null    float64
#  1   feature2  200 non-null    float64
#  2   feature3  200 non-null    float64
#  3   target    200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df
# Out:
#      feature1  feature2  feature3     target
# 0   -0.570563  1.420342  0.495580  -9.763182
# 1   -0.990563  0.556965  1.045064 -24.029355
# 2   -0.674728  0.150617  1.774645  45.616421
# 3    0.388250 -0.387127 -0.110229  34.135737
# 4    1.167882 -0.024104  0.145063  86.663647
# ..        ...       ...       ...        ...
# 195  0.255081 -0.231497 -0.239632  38.067836
# 196  0.276068 -0.648411 -0.077441  12.812755
# 197  0.122250 -1.157383  0.765721  70.454115
# 198 -0.914822 -0.897140 -0.784205 -93.235783
# 199  0.090717 -2.217418 -0.892406 -42.772129
#
# [200 rows x 4 columns]

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      feature1  feature2  feature3
# 0   -0.570563  1.420342  0.495580
# 1   -0.990563  0.556965  1.045064
# 2   -0.674728  0.150617  1.774645
# 3    0.388250 -0.387127 -0.110229
# 4    1.167882 -0.024104  0.145063
# ..        ...       ...       ...
# 195  0.255081 -0.231497 -0.239632
# 196  0.276068 -0.648411 -0.077441
# 197  0.122250 -1.157383  0.765721
# 198 -0.914822 -0.897140 -0.784205
# 199  0.090717 -2.217418 -0.892406
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      -9.763182
# 1     -24.029355
# 2      45.616421
# 3      34.135737
# 4      86.663647
#          ...
# 195    38.067836
# 196    12.812755
# 197    70.454115
# 198   -93.235783
# 199   -42.772129
# Name: target, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1  )

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train=scaler.transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear=LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([74.49356919, -0.27798315, 53.20013734])

# %%
linear.intercept_
# Out:
# -2.7463674662136026

# %%
y_pred=linear.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9498774008582507

# %% [markdown]
# 17. Write a Python script that performs polynomial regression (degree 3) on a synthetic dataset and plots the
# regression curve.

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
plt.scatter(x,y)
plt.show()

# %%
mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# 18. Write a Python script that performs multiple linear regression on a synthetic dataset with 5 features. Print
# the R-squared score and model coefficients.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=100,n_features=5,n_informative=5)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lin.predict(x_test)
from sklearn.metrics import r2_score
# Out:
#   Cell In[304], line 1
#     y_pred=lin.predict(x_test)1
#                               ^
# SyntaxError: invalid syntax

# %%
r2_score(y_pred,y_test)

# %% [markdown]
# 19. Write a Python script that generates synthetic data for linear regression, fits a model, and visualizes the
# data points along with the regression line.

# %%
from sklearn.datasets import make_regression
x,y=make_regression(n_samples=1000,n_features=1,n_informative=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
line=LinearRegression()

# %%
line.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=line.predict(x_test)

# %%
line.coef_
# Out:
# array([29.2126235])

# %%
 line.intercept_
# Out:
# 2.220446049250313e-16

# %%
plt.figure(figsize=(12,5))
plt.scatter(x,y)
plt.plot(x_test,y_pred,color="red")

plt.show()

# %%
#our datapoints passs through best fit line

# %% [markdown]
# 20. Create a synthetic dataset with 3 features and perform multiple linear regression. Print the model's Rsquared score and coefficients.

# %%
x,y=make_regression(n_samples=1000,n_features=3,n_informative=2)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
linear=LinearRegression()

# %%
linear
# Out:
# LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linear.predict(x_test)

# %%
linear.coef_
# Out:
# array([1.72956639e-14, 6.10646613e+00, 8.42403403e+01])

# %%
linear.intercept_
# Out:
# -4.218847493575595e-15

# %%
r2_score(y_pred,y_test)
# Out:
# 1.0

# %% [markdown]
# 21. Write a Python script that demonstrates how to serialize and deserialize machine learning models using
# joblib instead of pickling.

# %%
import joblib
filename = 'model_joblib.sav'
joblib.dump(rf, filename)

loaded_model = joblib.load(filename)
result = loaded_model.score(test, labels_test)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 3
#       1 import joblib
#       2 filename = 'model_joblib.sav'
# ----> 3 joblib.dump(rf, filename)
#       5 loaded_model = joblib.load(filename)
#       6 result = loaded_model.score(test, labels_test)
#
# NameError: name 'rf' is not defined

# %% [markdown]
# 22. Write a Python script to perform linear regression with categorical features using one-hot encoding. Use
# the Seaborn 'tips' dataset

# %%
df=sns.load_dataset("tips")

# %%
 df["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoded=OneHotEncoder()

# %%
encoded=encoded.fit_transform(df[["day"]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[276], line 1
# ----> 1 encoded=encoded.fit_transform(df[["day"]])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'fit_transform'

# %% [markdown]
# pd.DataFrame(encoded,columns=encoded.get_feature_names_out)

# %% [markdown]
# 23. Compare Ridge Regression with Linear Regression on a synthetic dataset and print the coefficients and Rsquared score.

# %%
from sklearn.datasets import make_regression
x,y=make_regression(n_samples=1000,n_features=3,n_informative=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import Ridge

# %%
linear=Ridge()

# %%
linear.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred=linear.predict(x_test)

# %%
linear.coef_
# Out:
# array([-1.14104627e-02,  3.73810467e-03,  9.13735186e+01])

# %%
linear.intercept_
# Out:
# -1.0421444743669017e-05

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,y_test)
# Out:
# 0.999997921032382

# %% [markdown]
# 24. Write a Python script that uses cross-validation to evaluate a Linear Regression model on a synthetic
# dataset.

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/diamonds.csv")
model = model.fit( df[ ["carat"] ], df["price"] )
import pandas as pd
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import mean_squared_error
import numpy as np

# Prepare the data
X = df.drop(["price"], axis = 1)
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=107)
# Fit the model on the training data using only the "carat" feature
model.fit(X_train[["carat"]], y_train)
# Make predictions on the test set
pred = model.predict(X_test[["carat"]])

 Calculate the Root Mean Squared Error (RMSE)
RMSE = mean_squared_error(y_test, pred, squared=False)
# Print the RMSE
print("Root Mean Squared Error (RMSE):", RMSE)
# Out:
#   Cell In[301], line 22
#     Calculate the Root Mean Squared Error (RMSE)
#     ^
# IndentationError: unexpected indent
